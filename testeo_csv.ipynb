# %%
import pandas as pd
df= pd.read_csv('resultado_scraping.csv')
df
# Out:
#                                   Equipos  Partidos_jugados  Partidos_ganados  \
# 0                      Belgrano (Córdoba)                 3                 2
# 1                                 Huracán                 2                 2
# 2                                   Lanús                 2                 2
# 3                Godoy Cruz Antonio Tomba                 2                 2
# 4                     Instituto (Córdoba)                 2                 1
# 5                                Platense                 2                 1
# 6                                   Tigre                 2                 1
# 7                       Newell's Old Boys                 2                 1
# 8                         Rosario Central                 2                 1
# 9                            Boca Juniors                 2                 1
# 10                      Sarmiento (Junín)                 3                 1
# ...
